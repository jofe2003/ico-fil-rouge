# %%
import pandas as pd

# %%
df_customers = pd.read_excel("2_detail_table_customers.xls")
df_customers.head()
# df_customers.shape
# df_customers.columns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_customers = pd.read_excel("2_detail_table_customers.xls")
#       2 df_customers.head()
#       3 # df_customers.shape
#       4 # df_customers.columns
#
# File c:\Users\João Felipe\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
df_vehicles = pd.read_excel("3_detail_table_vehicles.xls")
df_vehicles.shape
df_vehicles.head()
# Out:
#    ROUTE_ID  VEHICLE_NUMBER VEHICLE_CODE  VEHICLE_TOTAL_WEIGHT_KG  \
# 0   2946091               1    J92-T-826                     1058
# 1   2946091               2    A69-O-649                     1216
# 2   2946091               3    875-M-523                    12509
# 3   2946091               4    O76-T-703                     7271
# 4   2946091               5    O76-T-702                     7271
#
#    VEHICLE_TOTAL_VOLUME_M3  VEHICLE_FIXED_COST_KM  VEHICLE_VARIABLE_COST_KM  \
# 0                     3.15                      0                      0.20
# 1                     4.00                      0                      0.19
# 2                    20.84                      0                      0.51
# 3                    15.50                      0                      0.22
# 4                    15.50                      0                      0.22
#
#    VEHICLE_AVAILABLE_TIME_FROM_MIN  VEHICLE_AVAILABLE_TIME_TO_MIN  \
# ...

# %%
df_depots = pd.read_excel("4_detail_table_depots.xls")
df_depots.shape
df_depots.columns
# Out:
# Index(['ROUTE_ID', 'DEPOT_NUMBER', 'DEPOT_CODE', 'DEPOT_LATITUDE',
#        'DEPOT_LONGITUDE', 'DEPOT_AVAILABLE_TIME_FROM_MIN',
#        'DEPOT_AVAILABLE_TIME_TO_MIN', ' '],
#       dtype='object')

# %%
df_constraints = pd.read_excel("5_detail_table_constraints_sdvrp.xls")
df_constraints.shape
df_constraints.head()
# Out:
#    ROUTE_ID  SDVRP_CONSTRAINT_NUMBER SDVRP_CONSTRAINT_CUSTOMER_CODE  \
# 0   2946091                        1                         921336
# 1   2946091                        2                         131768
# 2   2946091                        3                          15208
# 3   2946091                        4                         132531
# 4   2946091                        5                         132531
#
#   SDVRP_CONSTRAINT_VEHICLE_CODE
# 0                     875-M-523
# 1                     875-M-523
# 2                     875-M-523
# 3                     O76-T-703
# 4                     875-M-523

# %%
df_cust = pd.read_excel("6_detail_table_cust_depots_distances.xls")
df_cust.head()
# Out:
#    ROUTE_ID  CUSTOMER_NUMBER  DEPOT_CODE CUSTOMER_CODE        DIRECTION  \
# 0   2946091                1        1000        138087  DEPOT->CUSTOMER
# 1   2946091                1        1000        138087  CUSTOMER->DEPOT
# 2   2946091                2        1000        138157  DEPOT->CUSTOMER
# 3   2946091                2        1000        138157  CUSTOMER->DEPOT
# 4   2946091                3        1000            26  DEPOT->CUSTOMER
#
#    DISTANCE_KM  TIME_DISTANCE_MIN
# 0       31.173             34.815
# 1       31.159             34.782
# 2       47.352             54.527
# 3       47.850             54.791
# 4       29.805             31.416
